# %% [markdown]
# # Principle Component Analysis (PCA)
#
# ### Key Equation: $Ax = \lambda b ~~ \text{for} ~~ n \times n $
#
# PCA is an orthogonal linear transformation that transforms the data to a new coordinate system such that the greatest variance by some projection of the data comes to lie on the first coordinate (called the first principal component), the second greatest variance on the second coordinate, and so on. This is an Unsupervised Learning Techniques - Which means we don't have a target variable.

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
pop = pd.read_csv('cars_small.csv')

# %%
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(pop.kmpl, pop.price , s = 150, alpha = 0.5)
sns.rugplot(pop.kmpl, color="m", ax=ax)
sns.rugplot(pop.price, color="m", vertical=True, ax=ax)

plt.xlabel('kmpl')
plt.ylabel('price')

# %% [markdown]
# ## Using sklearn

# %% [markdown]
# ## PCA using sklearn

# %%
X = np.array([pop.kmpl, pop.price]).T

# %%
X1 = np.subtract(X, np.mean(X, axis=0))

# %%
X_kmpl = np.array(X1[:,0])
X_price = np.array(X1[:,1])

# %%
plt.scatter(X_kmpl, X_price, s = 150)

# %%
cov_mat = np.cov(X1.T)
cov_mat
# Out:
# array([[  6.41361789e+00,  -2.31699593e+02],
#        [ -2.31699593e+02,   2.17473409e+04]])

# %%
from sklearn.decomposition import PCA

def pca_sklearn(X,n):
    X1 = np.subtract(X, np.mean(X, axis=0))   
    cov_mat = np.cov(X1.T)
    pca = PCA(n_components=n).fit(X1)
    X2 = pca.transform(X1)
    return (X2)

# %%
pca_sklearn(X1,2)
# Out:
# array([[  7.63085659e+01,  -4.96466321e-01],
#        [ -5.36883161e+01,   4.88769478e-01],
#        [  2.93069719e+01,  -3.95635803e-01],
#        [  1.52278678e+02,  -3.70614695e+00],
#        [ -1.14720016e+02,  -2.16105857e+00],
#        [ -2.02706496e+02,  -4.23421283e-01],
#        [ -1.71684134e+00,  -2.46517951e+00],
#        [ -8.73455827e+00,  -4.09049460e+00],
#        [  8.32730054e+01,  -3.87086737e+00],
#        [ -2.16922638e+01,  -5.21946977e-02],
#        [  7.63170902e+01,   3.03488262e-01],
#        [  1.95328449e+02,   7.35388999e-01],
#        [  7.93211821e+01,   6.71499098e-01],
#        [ -2.56856435e+01,   5.90393181e-01],
#        [ -2.76684180e+02,   2.06498812e+00],
#        [  1.31815145e+00,   8.02666692e-01],
#        [  1.82361153e+02,   3.87373999e+00],
#        [  2.49342432e+02,   1.75990196e+00],
#        [  1.05354869e+02,   3.69426913e+00],
#        [ -2.27651799e+02,   4.84268199e+00],
#        [  1.59308116e+02,  -9.80894310e-01],
# ...

# %%
PCA.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-ea11bc9a06bb> in <module>()
# ----> 1 PCA.fit_transform(X)
#
# TypeError: fit_transform() missing 1 required positional argument: 'X'

# %%
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(pop.kmpl, pop.price , s = 150, alpha = 0.5)
sns.rugplot(pop.kmpl, color="m", ax=ax)
sns.rugplot(pop.price, color="m", vertical=True, ax=ax)

plt.xlabel('kmpl')
plt.ylabel('price')
